# %%
import pandas as pd
df_Avacado=pd.read_csv("Avacado.csv",parse_dates=["Date"])
df_Avacado
# Out:
#       Unnamed: 0       Date  AveragePrice  Total Volume        4046  \
# 0              0 2015-12-27          1.33      64236.62     1036.74
# 1              1 2015-12-20          1.35      54876.98      674.28
# 2              2 2015-12-13          0.93     118220.22      794.70
# 3              3 2015-06-12          1.08      78992.15     1132.00
# 4              4 2015-11-29          1.28      51039.60      941.48
# ...          ...        ...           ...           ...         ...
# 1494          44 2016-02-21          0.89    6374019.03  1776499.00
# 1495          45 2016-02-14          0.82    6807283.15  1998149.71
# 1496          46 2016-07-02          0.70   10361698.17  2930343.28
# 1497          47 2016-01-31          0.88    6506673.96  2126066.85
# 1498          48 2016-01-24          0.88    6246380.73  1230068.19
#
#             4225       4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
df_Avacado.shape
# Out:
# (1499, 14)

# %%
df_Avacado.head()
# Out:
#    Unnamed: 0       Date  AveragePrice  Total Volume     4046       4225  \
# 0           0 2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1 2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2 2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3 2015-06-12          1.08      78992.15  1132.00   71976.41
# 4           4 2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# ...

# %%
df_Avacado.tail()
# Out:
#       Unnamed: 0       Date  AveragePrice  Total Volume        4046  \
# 1494          44 2016-02-21          0.89    6374019.03  1776499.00
# 1495          45 2016-02-14          0.82    6807283.15  1998149.71
# 1496          46 2016-07-02          0.70   10361698.17  2930343.28
# 1497          47 2016-01-31          0.88    6506673.96  2126066.85
# 1498          48 2016-01-24          0.88    6246380.73  1230068.19
#
#             4225       4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 1494  2073957.12  267508.94  2256053.97  2073467.05   167309.24     15277.68
# 1495  1974912.11  278558.48  2555662.85  2207054.69   333029.79     15578.37
# 1496  3950852.38  424389.60  3056112.91  2693843.02   344774.59     17495.30
# 1497  2069192.92  287234.03  2024180.16  1874982.24   134692.75     14505.17
# 1498  2457751.77  272665.17  2285895.60  2122673.09   147881.99     15340.52
#
#               type  year      region
# 1494  conventional  2016  California
# ...

# %%
df_Avacado.dtypes
# Out:
# Unnamed: 0               int64
# Date            datetime64[ns]
# AveragePrice           float64
# Total Volume           float64
# 4046                   float64
# 4225                   float64
# 4770                   float64
# Total Bags             float64
# Small Bags             float64
# Large Bags             float64
# XLarge Bags            float64
# type                    object
# year                     int64
# region                  object
# dtype: object

# %%
df_Avacado.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
df_Avacado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1499 entries, 0 to 1498
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1499 non-null   int64
#  1   Date          1499 non-null   datetime64[ns]
#  2   AveragePrice  1499 non-null   float64
#  3   Total Volume  1499 non-null   float64
#  4   4046          1499 non-null   float64
#  5   4225          1499 non-null   float64
#  6   4770          1499 non-null   float64
#  7   Total Bags    1499 non-null   float64
#  8   Small Bags    1499 non-null   float64
#  9   Large Bags    1499 non-null   float64
#  10  XLarge Bags   1499 non-null   float64
#  11  type          1499 non-null   object
#  12  year          1499 non-null   int64
#  13  region        1499 non-null   object
# dtypes: datetime64[ns](1), float64(9), int64(2), object(2)
# memory usage: 164.1+ KB

# %%
df_Avacado.describe()
# Out:
#         Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  1499.000000   1499.000000  1.499000e+03  1.499000e+03  1.499000e+03
# mean     27.149433      1.071648  1.606159e+06  6.499532e+05  6.134385e+05
# std      14.759589      0.185373  4.451437e+06  1.957500e+06  1.679887e+06
# min       0.000000      0.490000  3.875074e+04  4.677200e+02  1.783770e+03
# 25%      14.500000      0.970000  1.476080e+05  2.011391e+04  4.180462e+04
# 50%      29.000000      1.080000  4.072049e+05  8.399838e+04  1.242489e+05
# 75%      40.000000      1.190000  9.870613e+05  3.797120e+05  4.862557e+05
# max      51.000000      1.680000  4.465546e+07  1.893304e+07  1.895648e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.499000e+03  1.499000e+03  1.499000e+03  1.499000e+03    1499.000000
# mean   5.033842e+04  2.924288e+05  2.477303e+05  4.252172e+04    2176.742268
# ...

# %%
df_Avacado.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(df_Avacado.isnull(),annot=True)
plt.show()

# %%
df_Avacado.corr()
# Out:
#               Unnamed: 0  AveragePrice  Total Volume      4046      4225  \
# Unnamed: 0      1.000000     -0.046923      0.085219  0.086990  0.086812
# AveragePrice   -0.046923      1.000000     -0.134431 -0.186866 -0.084532
# Total Volume    0.085219     -0.134431      1.000000  0.985779  0.987114
# 4046            0.086990     -0.186866      0.985779  1.000000  0.952038
# 4225            0.086812     -0.084532      0.987114  0.952038  1.000000
# 4770            0.068637     -0.094525      0.934245  0.898991  0.927681
# Total Bags      0.070905     -0.102316      0.968895  0.932821  0.952995
# Small Bags      0.073416     -0.088021      0.961818  0.924690  0.945162
# Large Bags      0.056330     -0.171224      0.910639  0.885667  0.901002
# XLarge Bags    -0.060975     -0.039742      0.519846  0.473245  0.502827
# year            0.011157      0.146621     -0.002067 -0.037557 -0.004696
#
#                   4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
plt.hist(x="Total Volume",bins=50,data=df_Avacado)
plt.show()

# %%
sns.barplot(x=df_Avacado["Total Volume"],y=df_Avacado["AveragePrice"],data=df_Avacado)
plt.show()

# %%
sns.barplot(x=df_Avacado["Total Volume"],y=df_Avacado["4046"],data=df_Avacado)
plt.show()

# %%
sns.barplot(x=df_Avacado["Total Volume"],y=df_Avacado["4225"],data=df_Avacado)
plt.show()

# %%
sns.barplot(x=df_Avacado["Total Volume"],y=df_Avacado["4770"],data=df_Avacado)
plt.show()

# %%
df_Avacado.drop("type",axis=1,inplace=True)

# %%
df_Avacado.drop("Date",axis=1,inplace=True)

# %%
df_Avacado.drop("region",axis=1,inplace=True)

# %%
df_Avacado.skew()
# Out:
# Unnamed: 0     -0.252513
# AveragePrice   -0.169722
# Total Volume    6.191970
# 4046            6.026598
# 4225            6.385481
# 4770            5.409156
# Total Bags      5.409728
# Small Bags      5.399210
# Large Bags      5.170000
# XLarge Bags     5.792797
# year            1.932262
# dtype: float64

# %%
df_Avacado.dtypes
# Out:
# Unnamed: 0        int64
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# year              int64
# dtype: object

# %%
df_x=df_Avacado
x=df_Avacado.drop("Total Volume",axis=1)
y=df_Avacado["Total Volume"]

# %%
df_Avacado.skew()
# Out:
# Unnamed: 0     -0.252513
# AveragePrice   -0.169722
# Total Volume    6.191970
# 4046            6.026598
# 4225            6.385481
# 4770            5.409156
# Total Bags      5.409728
# Small Bags      5.399210
# Large Bags      5.170000
# XLarge Bags     5.792797
# year            1.932262
# dtype: float64

# %%
import numpy as np
for col in df_Avacado.columns:
    if df_Avacado.skew().loc[col]>0.55:
        df_Avacado[col]=np.log1p(df_Avacado[col])

# %%
df_Avacado.skew()
# Out:
# Unnamed: 0     -0.252513
# AveragePrice   -0.169722
# Total Volume    0.656086
# 4046           -0.164012
# 4225            0.169648
# 4770           -0.343624
# Total Bags      0.683653
# Small Bags      0.702637
# Large Bags     -0.901310
# XLarge Bags     0.783382
# year            1.932262
# dtype: float64

# %%
sns.pairplot(df_Avacado)
plt.show()

# %%
from scipy.stats import zscore
z_score=abs(zscore(df_Avacado))
print(df_Avacado.shape)
df_Avacado_final=df_Avacado.loc[(z_score<3).all(axis=1)]
print(df_Avacado_final.shape)
# Out:
# (1499, 11)
# (1481, 11)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(df_x)
x=pd.DataFrame(x,columns=df_x.columns)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=45,test_size=0.20)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
max_r_score=0
for r_state in range(45,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
    regr=linear_model.LinearRegression()
    regr.fit(x_train,y_train)
    y_pred=regr.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
print("max r2 score corresponding to ",final_r_state,"is",max_r_score)
# Out:
# max r2 score corresponding to  76 is 0.5485481019380738

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(linear_model.LinearRegression(),x,y,cv=5,scoring="r2").mean()
# Out:
# 1.0

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=76,test_size=0.20)
lreg=linear_model.LinearRegression()
lreg.fit(x_train,y_train)
y_pred=lreg.predict(x_test)

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("r2 score is:",r2_score(y_test,y_pred))
print("RMSE is: ",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2 score is: 1.0
# RMSE is:  2.0993101066385404e-15

# %%
import joblib
joblib.dump(lreg,"Avacado.pkl")
# Out:
# ['Avacado.pkl']
