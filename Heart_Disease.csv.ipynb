# %%
import pandas as pd
df_Heart=pd.read_csv("Heart_Disease.csv",na_values="?")
df_Heart
# Out:
#      age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     44    1   4     130.0  209.0  0.0        1    127.0    0.0      0.0
# 1     60    1   4     132.0  218.0  0.0        1    140.0    1.0      1.5
# 2     55    1   4     142.0  228.0  0.0        1    149.0    1.0      2.5
# 3     66    1   3     110.0  213.0  1.0        2     99.0    1.0      1.3
# 4     66    1   3     120.0    0.0  0.0        1    120.0    0.0     -0.5
# ..   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...
# 194   54    0   4     127.0  333.0  1.0        1    154.0    0.0      0.0
# 195   62    1   1       NaN  139.0  0.0        1      NaN    NaN      NaN
# 196   55    1   4     122.0  223.0  1.0        1    100.0    0.0      0.0
# 197   58    1   4       NaN  385.0  1.0        2      NaN    NaN      NaN
# 198   62    1   2     120.0  254.0  0.0        2     93.0    1.0      0.0
#
#      slope  ca  thal  num
# 0      NaN NaN   NaN    0
# ...

# %%
df_Heart.shape
# Out:
# (199, 14)

# %%
df_Heart.head()
# Out:
#    age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   44    1   4     130.0  209.0  0.0        1    127.0    0.0      0.0
# 1   60    1   4     132.0  218.0  0.0        1    140.0    1.0      1.5
# 2   55    1   4     142.0  228.0  0.0        1    149.0    1.0      2.5
# 3   66    1   3     110.0  213.0  1.0        2     99.0    1.0      1.3
# 4   66    1   3     120.0    0.0  0.0        1    120.0    0.0     -0.5
#
#    slope  ca  thal  num
# 0    NaN NaN   NaN    0
# 1    3.0 NaN   NaN    2
# 2    1.0 NaN   NaN    1
# 3    2.0 NaN   NaN    0
# 4    1.0 NaN   NaN    0

# %%
df_Heart.tail()
# Out:
#      age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 194   54    0   4     127.0  333.0  1.0        1    154.0    0.0      0.0
# 195   62    1   1       NaN  139.0  0.0        1      NaN    NaN      NaN
# 196   55    1   4     122.0  223.0  1.0        1    100.0    0.0      0.0
# 197   58    1   4       NaN  385.0  1.0        2      NaN    NaN      NaN
# 198   62    1   2     120.0  254.0  0.0        2     93.0    1.0      0.0
#
#      slope  ca  thal  num
# 194    NaN NaN   NaN    1
# 195    NaN NaN   NaN    0
# 196    NaN NaN   6.0    2
# 197    NaN NaN   NaN    0
# 198    NaN NaN   NaN    1

# %%
df_Heart.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num'],
#       dtype='object')

# %%
df_Heart["thal"]
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 194    NaN
# 195    NaN
# 196    6.0
# 197    NaN
# 198    NaN
# Name: thal, Length: 199, dtype: float64

# %%
df_Heart["ca"]
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 194   NaN
# 195   NaN
# 196   NaN
# 197   NaN
# 198   NaN
# Name: ca, Length: 199, dtype: float64

# %%
df_Heart["slope"]
# Out:
# 0      NaN
# 1      3.0
# 2      1.0
# 3      2.0
# 4      1.0
#       ...
# 194    NaN
# 195    NaN
# 196    NaN
# 197    NaN
# 198    NaN
# Name: slope, Length: 199, dtype: float64

# %%
df_Heart["chol"]
# Out:
# 0      209.0
# 1      218.0
# 2      228.0
# 3      213.0
# 4        0.0
#        ...
# 194    333.0
# 195    139.0
# 196    223.0
# 197    385.0
# 198    254.0
# Name: chol, Length: 199, dtype: float64

# %%
df_Heart["num"]
# Out:
# 0      0
# 1      2
# 2      1
# 3      0
# 4      0
#       ..
# 194    1
# 195    0
# 196    2
# 197    0
# 198    1
# Name: num, Length: 199, dtype: int64

# %%
df_Heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       199 non-null    int64
#  1   sex       199 non-null    int64
#  2   cp        199 non-null    int64
#  3   trestbps  143 non-null    float64
#  4   chol      192 non-null    float64
#  5   fbs       192 non-null    float64
#  6   restecg   199 non-null    int64
#  7   thalach   146 non-null    float64
#  8   exang     146 non-null    float64
#  9   oldpeak   143 non-null    float64
#  10  slope     97 non-null     float64
#  11  ca        2 non-null      float64
#  12  thal      34 non-null     float64
#  13  num       199 non-null    int64
# dtypes: float64(9), int64(5)
# memory usage: 21.9 KB

# %%
df_Heart.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps    float64
# chol        float64
# fbs         float64
# restecg       int64
# thalach     float64
# exang       float64
# oldpeak     float64
# slope       float64
# ca          float64
# thal        float64
# num           int64
# dtype: object

# %%
df_Heart.drop("ca",axis=1,inplace=True)

# %%
df_Heart.drop("slope",axis=1,inplace=True)

# %%
df_Heart.drop("thal",axis=1,inplace=True)

# %%
from sklearn.impute import SimpleImputer
imp=SimpleImputer(strategy="mean")
df_Heart["chol"]=imp.fit_transform(df_Heart["chol"].values.reshape(-1,1))
df_Heart
# Out:
#      age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  num
# 0     44    1   4     130.0  209.0  0.0        1    127.0    0.0      0.0    0
# 1     60    1   4     132.0  218.0  0.0        1    140.0    1.0      1.5    2
# 2     55    1   4     142.0  228.0  0.0        1    149.0    1.0      2.5    1
# 3     66    1   3     110.0  213.0  1.0        2     99.0    1.0      1.3    0
# 4     66    1   3     120.0    0.0  0.0        1    120.0    0.0     -0.5    0
# ..   ...  ...  ..       ...    ...  ...      ...      ...    ...      ...  ...
# 194   54    0   4     127.0  333.0  1.0        1    154.0    0.0      0.0    1
# 195   62    1   1       NaN  139.0  0.0        1      NaN    NaN      NaN    0
# 196   55    1   4     122.0  223.0  1.0        1    100.0    0.0      0.0    2
# 197   58    1   4       NaN  385.0  1.0        2      NaN    NaN      NaN    0
# 198   62    1   2     120.0  254.0  0.0        2     93.0    1.0      0.0    1
#
# [199 rows x 11 columns]

# %%
df_Heart.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps    float64
# chol        float64
# fbs         float64
# restecg       int64
# thalach     float64
# exang       float64
# oldpeak     float64
# num           int64
# dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(df_Heart.isnull(),annot=True)
plt.show()

# %%
df_Heart.isnull().sum()
# Out:
# age          0
# sex          0
# cp           0
# trestbps    56
# chol         0
# fbs          7
# restecg      0
# thalach     53
# exang       53
# oldpeak     56
# num          0
# dtype: int64

# %%
df_Heart.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  199.000000  199.000000  199.000000  143.000000  199.000000  192.000000
# mean    59.331658    0.969849    3.502513  133.720280  178.322917    0.354167
# std      7.827080    0.171433    0.796928   21.607056  112.144792    0.479510
# min     35.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 25%     55.000000    1.000000    3.000000  120.000000  119.500000    0.000000
# 50%     60.000000    1.000000    4.000000  130.000000  214.000000    0.000000
# 75%     64.000000    1.000000    4.000000  148.000000  254.000000    1.000000
# max     77.000000    1.000000    4.000000  190.000000  458.000000    1.000000
#
#           restecg     thalach       exang     oldpeak         num
# count  199.000000  146.000000  146.000000  143.000000  199.000000
# mean     0.733668  122.869863    0.643836    1.309091    1.517588
# std      0.684918   22.047680    0.480513    1.101082    1.222038
# ...

# %%
df_Heart.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000  0.033837 -0.039809  0.210249  0.065347  0.129817
# sex       0.033837  1.000000  0.037525  0.013440 -0.096953 -0.054766
# cp       -0.039809  0.037525  1.000000  0.096273  0.063650 -0.045454
# trestbps  0.210249  0.013440  0.096273  1.000000  0.173408  0.227936
# chol      0.065347 -0.096953  0.063650  0.173408  1.000000  0.160547
# fbs       0.129817 -0.054766 -0.045454  0.227936  0.160547  1.000000
# restecg   0.001487  0.060305  0.033617  0.106193  0.022824  0.169409
# thalach  -0.172810 -0.001115 -0.158766 -0.012169 -0.044694  0.059432
# exang     0.154844  0.017238  0.233857  0.221536  0.096342 -0.256466
# oldpeak   0.179773  0.105665  0.050777  0.115932 -0.005876 -0.115507
# num       0.286630  0.147190  0.167202  0.171946  0.075094  0.052617
#
#            restecg   thalach     exang   oldpeak       num
# age       0.001487 -0.172810  0.154844  0.179773  0.286630
# ...

# %%
plt.hist("age",bins=20,data=df_Heart)
# Out:
# (array([ 2.,  1.,  4.,  2.,  2.,  2.,  6.,  9.,  7., 21., 31., 20., 27.,
#         23.,  9.,  9.,  9.,  5.,  5.,  5.]),
#  array([35. , 37.1, 39.2, 41.3, 43.4, 45.5, 47.6, 49.7, 51.8, 53.9, 56. ,
#         58.1, 60.2, 62.3, 64.4, 66.5, 68.6, 70.7, 72.8, 74.9, 77. ]),
#  <a list of 20 Patch objects>)

# %%
sns.barplot(x=df_Heart["age"],y=df_Heart["sex"],data=df_Heart)
plt.show()

# %%
sns.barplot(x=df_Heart["sex"],y=df_Heart["num"],data=df_Heart)
plt.show()

# %%
df_Heart.skew()
# Out:
# age        -0.397178
# sex        -5.537073
# cp         -1.641267
# trestbps   -1.277021
# chol       -0.563256
# fbs         0.614662
# restecg     0.396540
# thalach     0.118186
# exang      -0.606990
# oldpeak     0.375154
# num         0.302681
# dtype: float64

# %%
from sklearn.impute import SimpleImputer
imp=SimpleImputer(strategy="mean")
df_Heart["trestbps"]=imp.fit_transform(df_Heart["trestbps"].values.reshape(-1,1))
df_Heart
# Out:
#      age  sex  cp   trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     44    1   4  130.00000  209.0  0.0        1    127.0    0.0      0.0
# 1     60    1   4  132.00000  218.0  0.0        1    140.0    1.0      1.5
# 2     55    1   4  142.00000  228.0  0.0        1    149.0    1.0      2.5
# 3     66    1   3  110.00000  213.0  1.0        2     99.0    1.0      1.3
# 4     66    1   3  120.00000    0.0  0.0        1    120.0    0.0     -0.5
# ..   ...  ...  ..        ...    ...  ...      ...      ...    ...      ...
# 194   54    0   4  127.00000  333.0  1.0        1    154.0    0.0      0.0
# 195   62    1   1  133.72028  139.0  0.0        1      NaN    NaN      NaN
# 196   55    1   4  122.00000  223.0  1.0        1    100.0    0.0      0.0
# 197   58    1   4  133.72028  385.0  1.0        2      NaN    NaN      NaN
# 198   62    1   2  120.00000  254.0  0.0        2     93.0    1.0      0.0
#
#      num
# 0      0
# 1      2
# 2      1
# 3      0
# 4      0
# ...

# %%
from sklearn.impute import SimpleImputer
imp=SimpleImputer(strategy="mean")
df_Heart["thalach"]=imp.fit_transform(df_Heart["thalach"].values.reshape(-1,1))
df_Heart
# Out:
#      age  sex  cp   trestbps   chol  fbs  restecg     thalach  exang  oldpeak  \
# 0     44    1   4  130.00000  209.0  0.0        1  127.000000    0.0      0.0
# 1     60    1   4  132.00000  218.0  0.0        1  140.000000    1.0      1.5
# 2     55    1   4  142.00000  228.0  0.0        1  149.000000    1.0      2.5
# 3     66    1   3  110.00000  213.0  1.0        2   99.000000    1.0      1.3
# 4     66    1   3  120.00000    0.0  0.0        1  120.000000    0.0     -0.5
# ..   ...  ...  ..        ...    ...  ...      ...         ...    ...      ...
# 194   54    0   4  127.00000  333.0  1.0        1  154.000000    0.0      0.0
# 195   62    1   1  133.72028  139.0  0.0        1  122.869863    NaN      NaN
# 196   55    1   4  122.00000  223.0  1.0        1  100.000000    0.0      0.0
# 197   58    1   4  133.72028  385.0  1.0        2  122.869863    NaN      NaN
# 198   62    1   2  120.00000  254.0  0.0        2   93.000000    1.0      0.0
#
#      num
# 0      0
# 1      2
# ...

# %%
from sklearn.impute import SimpleImputer
imp=SimpleImputer(strategy="mean")
df_Heart["exang"]=imp.fit_transform(df_Heart["exang"].values.reshape(-1,1))
df_Heart
# Out:
#      age  sex  cp   trestbps   chol  fbs  restecg     thalach     exang  \
# 0     44    1   4  130.00000  209.0  0.0        1  127.000000  0.000000
# 1     60    1   4  132.00000  218.0  0.0        1  140.000000  1.000000
# 2     55    1   4  142.00000  228.0  0.0        1  149.000000  1.000000
# 3     66    1   3  110.00000  213.0  1.0        2   99.000000  1.000000
# 4     66    1   3  120.00000    0.0  0.0        1  120.000000  0.000000
# ..   ...  ...  ..        ...    ...  ...      ...         ...       ...
# 194   54    0   4  127.00000  333.0  1.0        1  154.000000  0.000000
# 195   62    1   1  133.72028  139.0  0.0        1  122.869863  0.643836
# 196   55    1   4  122.00000  223.0  1.0        1  100.000000  0.000000
# 197   58    1   4  133.72028  385.0  1.0        2  122.869863  0.643836
# 198   62    1   2  120.00000  254.0  0.0        2   93.000000  1.000000
#
#      oldpeak  num
# 0        0.0    0
# 1        1.5    2
# 2        2.5    1
# 3        1.3    0
# ...

# %%
from sklearn.impute import SimpleImputer
imp=SimpleImputer(strategy="median")
df_Heart["fbs"]=imp.fit_transform(df_Heart["fbs"].values.reshape(-1,1))
df_Heart
# Out:
#      age  sex  cp   trestbps   chol  fbs  restecg     thalach     exang  \
# 0     44    1   4  130.00000  209.0  0.0        1  127.000000  0.000000
# 1     60    1   4  132.00000  218.0  0.0        1  140.000000  1.000000
# 2     55    1   4  142.00000  228.0  0.0        1  149.000000  1.000000
# 3     66    1   3  110.00000  213.0  1.0        2   99.000000  1.000000
# 4     66    1   3  120.00000    0.0  0.0        1  120.000000  0.000000
# ..   ...  ...  ..        ...    ...  ...      ...         ...       ...
# 194   54    0   4  127.00000  333.0  1.0        1  154.000000  0.000000
# 195   62    1   1  133.72028  139.0  0.0        1  122.869863  0.643836
# 196   55    1   4  122.00000  223.0  1.0        1  100.000000  0.000000
# 197   58    1   4  133.72028  385.0  1.0        2  122.869863  0.643836
# 198   62    1   2  120.00000  254.0  0.0        2   93.000000  1.000000
#
#      oldpeak  num
# 0        0.0    0
# 1        1.5    2
# 2        2.5    1
# 3        1.3    0
# ...

# %%
df_Heart.skew()
# Out:
# age        -0.397178
# sex        -5.537073
# cp         -1.641267
# trestbps   -1.501953
# chol       -0.563256
# fbs         0.672579
# restecg     0.396540
# thalach     0.137597
# exang      -0.706686
# oldpeak     0.375154
# num         0.302681
# dtype: float64

# %%
from sklearn.impute import SimpleImputer
imp=SimpleImputer(strategy="median")
df_Heart["oldpeak"]=imp.fit_transform(df_Heart["oldpeak"].values.reshape(-1,1))
df_Heart
# Out:
#      age  sex  cp   trestbps   chol  fbs  restecg     thalach     exang  \
# 0     44    1   4  130.00000  209.0  0.0        1  127.000000  0.000000
# 1     60    1   4  132.00000  218.0  0.0        1  140.000000  1.000000
# 2     55    1   4  142.00000  228.0  0.0        1  149.000000  1.000000
# 3     66    1   3  110.00000  213.0  1.0        2   99.000000  1.000000
# 4     66    1   3  120.00000    0.0  0.0        1  120.000000  0.000000
# ..   ...  ...  ..        ...    ...  ...      ...         ...       ...
# 194   54    0   4  127.00000  333.0  1.0        1  154.000000  0.000000
# 195   62    1   1  133.72028  139.0  0.0        1  122.869863  0.643836
# 196   55    1   4  122.00000  223.0  1.0        1  100.000000  0.000000
# 197   58    1   4  133.72028  385.0  1.0        2  122.869863  0.643836
# 198   62    1   2  120.00000  254.0  0.0        2   93.000000  1.000000
#
#      oldpeak  num
# 0        0.0    0
# 1        1.5    2
# 2        2.5    1
# 3        1.3    0
# ...

# %%
import numpy as np
for col in df_Heart.columns:
    if df_Heart.skew().loc[col]>0.55:
        df_Heart[col]=np.log1p(df_Heart[col])

# %%
df_Heart.skew()
# Out:
# age        -0.397178
# sex        -5.537073
# cp         -1.641267
# trestbps   -1.501953
# chol       -0.563256
# fbs         0.672579
# restecg     0.396540
# thalach     0.137597
# exang      -0.706686
# oldpeak     0.264024
# num         0.302681
# dtype: float64

# %%
df_x=df_Heart.drop(columns=["num"])
y=pd.DataFrame(df_Heart["num"])

# %%
import warnings
warnings.filterwarnings("ignore")
from scipy.stats import zscore
z_score=abs(zscore(df_Heart))
print(df_Heart.shape)
df_Heart_final=df_Heart.loc[(z_score<3).all(axis=1)]
print(df_Heart_final.shape)
# Out:
# (199, 11)
# (180, 11)

# %%
sns.pairplot(df_Heart)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(df_x)
x=pd.DataFrame(x,columns=df_x.columns)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.20)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
import warnings
warnings.filterwarnings("ignore")

# %%
gnb=GaussianNB()
gnb.fit(x_train,y_train)
predgnb=gnb.predict(x_test)
print(accuracy_score(y_test,predgnb))
print(confusion_matrix(y_test,predgnb))
print(classification_report(y_test,predgnb))
# Out:
# 0.15
# [[0 1 3 4 0]
#  [0 1 8 3 0]
#  [0 0 3 3 0]
#  [0 0 8 1 1]
#  [0 0 1 2 1]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         8
#            1       0.50      0.08      0.14        12
#            2       0.13      0.50      0.21         6
#            3       0.08      0.10      0.09        10
#            4       0.50      0.25      0.33         4
#
#     accuracy                           0.15        40
#    macro avg       0.24      0.19      0.15        40
# weighted avg       0.24      0.15      0.13        40

# %%
svc=SVC()
svc.fit(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.375
# [[3 5 0 0 0]
#  [3 7 2 0 0]
#  [2 2 2 0 0]
#  [4 1 2 3 0]
#  [1 0 1 2 0]]
#               precision    recall  f1-score   support
#
#            0       0.23      0.38      0.29         8
#            1       0.47      0.58      0.52        12
#            2       0.29      0.33      0.31         6
#            3       0.60      0.30      0.40        10
#            4       0.00      0.00      0.00         4
#
#     accuracy                           0.38        40
#    macro avg       0.32      0.32      0.30        40
# weighted avg       0.38      0.38      0.36        40

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
preddtc=dtc.predict(x_test)
print(accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# 0.3
# [[3 4 1 0 0]
#  [4 2 3 2 1]
#  [2 1 3 0 0]
#  [4 0 2 4 0]
#  [2 0 1 1 0]]
#               precision    recall  f1-score   support
#
#            0       0.20      0.38      0.26         8
#            1       0.29      0.17      0.21        12
#            2       0.30      0.50      0.37         6
#            3       0.57      0.40      0.47        10
#            4       0.00      0.00      0.00         4
#
#     accuracy                           0.30        40
#    macro avg       0.27      0.29      0.26        40
# weighted avg       0.31      0.30      0.29        40

# %%
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
preddtc=knn.predict(x_test)
print(accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# 0.375
# [[5 1 1 1 0]
#  [5 6 1 0 0]
#  [2 1 1 2 0]
#  [4 1 2 3 0]
#  [1 0 2 1 0]]
#               precision    recall  f1-score   support
#
#            0       0.29      0.62      0.40         8
#            1       0.67      0.50      0.57        12
#            2       0.14      0.17      0.15         6
#            3       0.43      0.30      0.35        10
#            4       0.00      0.00      0.00         4
#
#     accuracy                           0.38        40
#    macro avg       0.31      0.32      0.30        40
# weighted avg       0.39      0.38      0.36        40

# %%
svc=SVC(kernel="poly")
svc.fit(x_train,y_train)
svc.score(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.35
# [[2 6 0 0 0]
#  [1 9 2 0 0]
#  [1 4 0 1 0]
#  [0 7 0 3 0]
#  [0 2 2 0 0]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.25      0.33         8
#            1       0.32      0.75      0.45        12
#            2       0.00      0.00      0.00         6
#            3       0.75      0.30      0.43        10
#            4       0.00      0.00      0.00         4
#
#     accuracy                           0.35        40
#    macro avg       0.31      0.26      0.24        40
# weighted avg       0.38      0.35      0.31        40

# %%
def svmkernel(ker):
    svc=SVC(kernel=ker)
    svc.fit(x_train,y_train)
    svc.score(x_train,y_train)
    predsvc=svc.predict(x_test)
    print(accuracy_score(y_test,predsvc))
    print(confusion_matrix(y_test,predsvc))
    print(classification_report(y_test,predsvc))

# %%
svmkernel("rbf")
# Out:
# 0.375
# [[3 5 0 0 0]
#  [3 7 2 0 0]
#  [2 2 2 0 0]
#  [4 1 2 3 0]
#  [1 0 1 2 0]]
#               precision    recall  f1-score   support
#
#            0       0.23      0.38      0.29         8
#            1       0.47      0.58      0.52        12
#            2       0.29      0.33      0.31         6
#            3       0.60      0.30      0.40        10
#            4       0.00      0.00      0.00         4
#
#     accuracy                           0.38        40
#    macro avg       0.32      0.32      0.30        40
# weighted avg       0.38      0.38      0.36        40

# %%
svmkernel("poly")
# Out:
# 0.35
# [[2 6 0 0 0]
#  [1 9 2 0 0]
#  [1 4 0 1 0]
#  [0 7 0 3 0]
#  [0 2 2 0 0]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.25      0.33         8
#            1       0.32      0.75      0.45        12
#            2       0.00      0.00      0.00         6
#            3       0.75      0.30      0.43        10
#            4       0.00      0.00      0.00         4
#
#     accuracy                           0.35        40
#    macro avg       0.31      0.26      0.24        40
# weighted avg       0.38      0.35      0.31        40

# %%
df1=pd.DataFrame(predsvc)
df1.to_csv("svc_prediction.csv")
